# %% [markdown]
# ### Project Details
#
# * DOMAIN: Entertainment
#
# * CONTEXT: Company X owns a movie application and repository which caters movie streaming to millions of users who on subscription basis.
# Company wants to automate the process of cast and crew information in each scene from a movie such that when a user pauses on the
# movie and clicks on cast information button, the app will show details of the actor in the scene. Company has an in-house computer vision
# and multimedia experts who need to detect faces from screen shots from the movie scene.
#
# * DATA DESCRIPTION: The dataset comprises of images and its mask where there is a human face.
# * PROJECT OBJECTIVE: Face detection from training images.

# %% [markdown]
# ### Attributions
#
# * Dataset : http://shuoyang1213.me/WIDERFACE/
# * MobileNet paper : https://arxiv.org/pdf/1704.04861.pdf

# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches
#https://matplotlib.org/stable/api/_as_gen/matplotlib.patches.Patch.html#:~:text=A%20patch%20is%20a%202D,Description
from PIL import Image
import csv

# %%
from keras import Model
from keras.applications.mobilenet import MobileNet, preprocess_input
from keras.applications.vgg16 import VGG16
from keras.layers import GlobalAveragePooling2D 
#https://paperswithcode.com/method/global-average-pooling#:~:text=Global%20Average%20Pooling%20is%20a,in%20the%20last%20mlpconv%20layer.
#https://adventuresinmachinelearning.com/global-average-pooling-convolutional-neural-networks/
from keras.layers import RepeatVector,Conv1D,Flatten,Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from keras.layers import Conv2D, Reshape
from keras.utils import Sequence
from keras.backend import epsilon #Returns a fuzz factor(1e-7)
import tensorflow as tf
import tensorflow
from keras.applications.resnet50 import ResNet50,preprocess_input

# %% [markdown]
# Mounting the drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ### Loading the dataset from npy file

# %%
data = np.load('/content/drive/MyDrive/glearn/ACV/Dataset- Images.npy', allow_pickle=True)

# %%
data.shape
# Out:
# (409, 2)

# %% [markdown]
# ### The first image

# %%
plt.imshow(data[0][0])

# %% [markdown]
# ### Image Attributes

# %%
data[0][1]
# Out:
# [{'imageHeight': 333,
#   'imageWidth': 650,
#   'label': ['Face'],
#   'notes': '',
#   'points': [{'x': 0.08615384615384615, 'y': 0.3063063063063063},
#    {'x': 0.1723076923076923, 'y': 0.45345345345345345}]},
#  {'imageHeight': 333,
#   'imageWidth': 650,
#   'label': ['Face'],
#   'notes': '',
#   'points': [{'x': 0.583076923076923, 'y': 0.2912912912912913},
#    {'x': 0.6584615384615384, 'y': 0.46846846846846846}]}]

# %% [markdown]
# Defining a function for image plotting

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %% [markdown]
# ### Displaying an image from the dataset selected randomly

# %%
img_no = np.random.randint(0, data.shape[0])
print("Image number " + str(img_no))
plt.imshow(data[img_no][0])
# Out:
# Image number 45

# %%
data[img_no][1]
# Out:
# [{'imageHeight': 643,
#   'imageWidth': 920,
#   'label': ['Face'],
#   'notes': '',
#   'points': [{'x': 0.1608695652173913, 'y': 0.1104199066874028},
#    {'x': 0.23695652173913043, 'y': 0.2099533437013997}]},
#  {'imageHeight': 643,
#   'imageWidth': 920,
#   'label': ['Face'],
#   'notes': '',
#   'points': [{'x': 0.11956521739130435, 'y': 0.4276827371695179},
#    {'x': 0.21739130434782608, 'y': 0.552099533437014}]}]

# %% [markdown]
# #### Applying a fixed rectangular mask over an image and noticing the original and masked images together

# %%
# load the original input image and display it to our screen
image = data[img_no][0]
plt_imshow("Original", image)

# a mask is the same size as our image, but has only two pixel
# values, 0 and 255 -- pixels with a value of 0 (background) are
# ignored in the original image while mask pixels with a value of
# 255 (foreground) are allowed to be kept
mask = np.zeros(image.shape[:2], dtype="uint8")
cv2.rectangle(mask, (0, 90), (290, 450), 255, -1)
plt_imshow("Rectangular Mask", mask)

# apply our mask -- notice how only the person in the mask is
# cropped out because these are fixed coordinates
masked = cv2.bitwise_and(image, image, mask=mask)
plt_imshow("Mask Applied to Image", masked)

# %% [markdown]
# ### Define the neccessary parameters

# %%
ALPHA = 1 # Width hyper parameter for MobileNet (0.25, 0.5, 0.75, 1.0). Higher width means more accurate but slower

IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224

HEIGHT_CELLS = 28
WIDTH_CELLS = 28

IMAGE_SIZE = 224

# %% [markdown]
# ### Preprocess Image in a format compatible with Mobilenet

# %%
X, y = [],[]

for i, img in enumerate(data):
  resized_img = cv2.resize(img[0], (IMAGE_HEIGHT,IMAGE_WIDTH))
  resized_img = cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB)
  #plt_imshow("Original", resized_img)
  X.append(preprocess_input(np.array(resized_img, dtype=np.float32)))

  mask = np.zeros(resized_img.shape[:2], dtype="uint8")

  for face in img[1]:
    if 'Face' in face['label']:
      x1 = np.round(IMAGE_SIZE*face['points'][0]['x'])
      y1 = np.round(IMAGE_SIZE*face['points'][0]['y'])
      x2 = np.round(IMAGE_SIZE*face['points'][1]['x'])
      y2 = np.round(IMAGE_SIZE*face['points'][1]['y'])

      #Draw a filled recatngle on the mask image
      cv2.rectangle(mask, (int(x1),int(y1),int(x2),int(y2)), 255, -1)

  #plt_imshow("Rectangular Mask", mask[0])
  resized_img = cv2.bitwise_and(resized_img, resized_img, mask = mask)
  #plt_imshow("Mask Applied to Image", resized_img)
  #break;
  resized_img = cv2.resize(resized_img, (HEIGHT_CELLS,WIDTH_CELLS))
  resized_img = 1.0*(resized_img[:,:,0]>0.2)
  y.append(np.squeeze(resized_img))

X = np.array(X)
y = np.array(y)

# %%
X.shape, y.shape
# Out:
# ((409, 224, 224, 3), (409, 28, 28))

# %%
import matplotlib.pyplot as plt
plt.imshow(X[6])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(y[6])

# %%
X = np.array(X)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (306, 224, 224, 3)
# (103, 224, 224, 3)
# (306, 28, 28)
# (103, 28, 28)

# %% [markdown]
# ## Building the graph

# %%
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.layers import Concatenate, Conv2D, Reshape, UpSampling2D
from tensorflow.keras.models import Model

def create_model(trainable=True):
    model = MobileNet(input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3), include_top=False, alpha=ALPHA, weights="imagenet")

    for layer in model.layers:
        layer.trainable = trainable

    block1 = model.get_layer("conv_pw_5_relu").output
    block2 = model.get_layer("conv_pw_11_relu").output
    block3 = model.get_layer("conv_pw_13_relu").output

    x = Concatenate()([UpSampling2D()(block3), block2])
    x = Concatenate()([UpSampling2D()(x), block1])

    x = Conv2D(1, kernel_size=1, activation="sigmoid")(x)
    x = Reshape((HEIGHT_CELLS, WIDTH_CELLS))(x)

    return Model(inputs=model.input, outputs=x)

# %% [markdown]
# ## Define Dice Coefficient

# %%
def dice_coefficient(y_true, y_pred):
    numerator = 2 * tensorflow.reduce_sum(y_true * y_pred)
    denominator = tensorflow.reduce_sum(y_true + y_pred)

    return numerator / (denominator + tensorflow.keras.backend.epsilon())

# %% [markdown]
# ## Define Loss Function

# %%
def loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - tensorflow.keras.backend.log(dice_coefficient(y_true, y_pred) + tensorflow.keras.backend.epsilon())

# %% [markdown]
# ## Create the model and print summary

# %%
model = create_model(False)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_3[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 112, 112, 32) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)     (None, 112, 112, 32) 288         conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_bn (BatchNormalizatio (None, 112, 112, 32) 128         conv_dw_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_relu (ReLU)           (None, 112, 112, 32) 0           conv_dw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_1 (Conv2D)              (None, 112, 112, 64) 2048        conv_dw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_bn (BatchNormalizatio (None, 112, 112, 64) 256         conv_pw_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_relu (ReLU)           (None, 112, 112, 64) 0           conv_pw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_2 (ZeroPadding2D)      (None, 113, 113, 64) 0           conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)     (None, 56, 56, 64)   576         conv_pad_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_bn (BatchNormalizatio (None, 56, 56, 64)   256         conv_dw_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_relu (ReLU)           (None, 56, 56, 64)   0           conv_dw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_2 (Conv2D)              (None, 56, 56, 128)  8192        conv_dw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_pw_2[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_relu (ReLU)           (None, 56, 56, 128)  0           conv_pw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)     (None, 56, 56, 128)  1152        conv_pw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_dw_3[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_relu (ReLU)           (None, 56, 56, 128)  0           conv_dw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_3 (Conv2D)              (None, 56, 56, 128)  16384       conv_dw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_pw_3[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_relu (ReLU)           (None, 56, 56, 128)  0           conv_pw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_4 (ZeroPadding2D)      (None, 57, 57, 128)  0           conv_pw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)     (None, 28, 28, 128)  1152        conv_pad_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv_dw_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_relu (ReLU)           (None, 28, 28, 128)  0           conv_dw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_4 (Conv2D)              (None, 28, 28, 256)  32768       conv_dw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_pw_4[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_relu (ReLU)           (None, 28, 28, 256)  0           conv_pw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)     (None, 28, 28, 256)  2304        conv_pw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_dw_5[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_relu (ReLU)           (None, 28, 28, 256)  0           conv_dw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_5 (Conv2D)              (None, 28, 28, 256)  65536       conv_dw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_pw_5[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_relu (ReLU)           (None, 28, 28, 256)  0           conv_pw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_6 (ZeroPadding2D)      (None, 29, 29, 256)  0           conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)     (None, 14, 14, 256)  2304        conv_pad_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv_dw_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_relu (ReLU)           (None, 14, 14, 256)  0           conv_dw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_6 (Conv2D)              (None, 14, 14, 512)  131072      conv_dw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_6[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_7[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_7 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_7[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_8[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_8 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_8[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_9[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_9 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_9[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_10 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        conv_pw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_dw_10[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_relu (ReLU)          (None, 14, 14, 512)  0           conv_dw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_10 (Conv2D)             (None, 14, 14, 512)  262144      conv_dw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_pw_10[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_relu (ReLU)          (None, 14, 14, 512)  0           conv_pw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_11 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        conv_pw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_dw_11[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_relu (ReLU)          (None, 14, 14, 512)  0           conv_dw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_11 (Conv2D)             (None, 14, 14, 512)  262144      conv_dw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_pw_11[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_relu (ReLU)          (None, 14, 14, 512)  0           conv_pw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_12 (ZeroPadding2D)     (None, 15, 15, 512)  0           conv_pw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_12 (DepthwiseConv2D)    (None, 7, 7, 512)    4608        conv_pad_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_bn (BatchNormalizati (None, 7, 7, 512)    2048        conv_dw_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_relu (ReLU)          (None, 7, 7, 512)    0           conv_dw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_12 (Conv2D)             (None, 7, 7, 1024)   524288      conv_dw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_pw_12[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_relu (ReLU)          (None, 7, 7, 1024)   0           conv_pw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_13 (DepthwiseConv2D)    (None, 7, 7, 1024)   9216        conv_pw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_dw_13[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_relu (ReLU)          (None, 7, 7, 1024)   0           conv_dw_13_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_13 (Conv2D)             (None, 7, 7, 1024)   1048576     conv_dw_13_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_pw_13[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_relu (ReLU)          (None, 7, 7, 1024)   0           conv_pw_13_bn[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 14, 14, 1024) 0           conv_pw_13_relu[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 1536) 0           up_sampling2d_4[0][0]
#                                                                  conv_pw_11_relu[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 28, 28, 1536) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 28, 28, 1792) 0           up_sampling2d_5[0][0]
#                                                                  conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 1)    1793        concatenate_5[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 28, 28)       0           conv2d_2[0][0]
# ==================================================================================================
# Total params: 3,230,657
# Trainable params: 1,793
# Non-trainable params: 3,228,864
# __________________________________________________________________________________________________

# %% [markdown]
# ### Compile the model
# - Define optimizer
# - Define metrics
# - Define loss

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy

optimizer = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss=loss, optimizer=optimizer, metrics=[dice_coefficient])

# %% [markdown]
# ## Define callbacks

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint = ModelCheckpoint("model-{val_loss:.2f}.h5", monitor="val_loss", verbose=1, save_best_only=True, save_weights_only=True)

stop = EarlyStopping(monitor="val_loss", patience=5)

reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.2, patience=5, min_lr=1e-6, verbose=1)

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ## Fit the model

# %%
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs=300, batch_size=32, verbose=1, callbacks=[checkpoint])
# Out:
# Epoch 1/300
# 10/10 [==============================] - 2s 83ms/step - loss: 1.7192 - dice_coefficient: 0.4384 - val_loss: 1.7208 - val_dice_coefficient: 0.4482
#
# Epoch 00001: val_loss improved from inf to 1.72082, saving model to model-1.72.h5
# Epoch 2/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.6036 - dice_coefficient: 0.4810 - val_loss: 1.6704 - val_dice_coefficient: 0.4563
#
# Epoch 00002: val_loss improved from 1.72082 to 1.67041, saving model to model-1.67.h5
# Epoch 3/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.5843 - dice_coefficient: 0.4834 - val_loss: 1.6276 - val_dice_coefficient: 0.4574
#
# Epoch 00003: val_loss improved from 1.67041 to 1.62759, saving model to model-1.63.h5
# Epoch 4/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.5624 - dice_coefficient: 0.4763 - val_loss: 1.5882 - val_dice_coefficient: 0.4674
#
# Epoch 00004: val_loss improved from 1.62759 to 1.58820, saving model to model-1.59.h5
# Epoch 5/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.5038 - dice_coefficient: 0.4969 - val_loss: 1.5564 - val_dice_coefficient: 0.4724
#
# Epoch 00005: val_loss improved from 1.58820 to 1.55641, saving model to model-1.56.h5
# Epoch 6/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.5009 - dice_coefficient: 0.4956 - val_loss: 1.5275 - val_dice_coefficient: 0.4810
#
# Epoch 00006: val_loss improved from 1.55641 to 1.52752, saving model to model-1.53.h5
# Epoch 7/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.4566 - dice_coefficient: 0.5072 - val_loss: 1.5043 - val_dice_coefficient: 0.4845
#
# Epoch 00007: val_loss improved from 1.52752 to 1.50429, saving model to model-1.50.h5
# Epoch 8/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.4641 - dice_coefficient: 0.4959 - val_loss: 1.4845 - val_dice_coefficient: 0.4881
#
# Epoch 00008: val_loss improved from 1.50429 to 1.48453, saving model to model-1.48.h5
# Epoch 9/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.4305 - dice_coefficient: 0.5108 - val_loss: 1.4657 - val_dice_coefficient: 0.4977
#
# Epoch 00009: val_loss improved from 1.48453 to 1.46572, saving model to model-1.47.h5
# Epoch 10/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.3714 - dice_coefficient: 0.5211 - val_loss: 1.4518 - val_dice_coefficient: 0.4976
#
# Epoch 00010: val_loss improved from 1.46572 to 1.45182, saving model to model-1.45.h5
# Epoch 11/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.3642 - dice_coefficient: 0.5233 - val_loss: 1.4393 - val_dice_coefficient: 0.5000
#
# Epoch 00011: val_loss improved from 1.45182 to 1.43930, saving model to model-1.44.h5
# Epoch 12/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.3728 - dice_coefficient: 0.5217 - val_loss: 1.4259 - val_dice_coefficient: 0.5084
#
# Epoch 00012: val_loss improved from 1.43930 to 1.42587, saving model to model-1.43.h5
# Epoch 13/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.3258 - dice_coefficient: 0.5417 - val_loss: 1.4157 - val_dice_coefficient: 0.5094
#
# Epoch 00013: val_loss improved from 1.42587 to 1.41567, saving model to model-1.42.h5
# Epoch 14/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.3459 - dice_coefficient: 0.5275 - val_loss: 1.4082 - val_dice_coefficient: 0.5082
#
# Epoch 00014: val_loss improved from 1.41567 to 1.40817, saving model to model-1.41.h5
# Epoch 15/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.2981 - dice_coefficient: 0.5424 - val_loss: 1.3978 - val_dice_coefficient: 0.5149
#
# Epoch 00015: val_loss improved from 1.40817 to 1.39780, saving model to model-1.40.h5
# Epoch 16/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.2968 - dice_coefficient: 0.5460 - val_loss: 1.3894 - val_dice_coefficient: 0.5191
#
# Epoch 00016: val_loss improved from 1.39780 to 1.38945, saving model to model-1.39.h5
# Epoch 17/300
# 10/10 [==============================] - 0s 52ms/step - loss: 1.2991 - dice_coefficient: 0.5443 - val_loss: 1.3823 - val_dice_coefficient: 0.5209
#
# Epoch 00017: val_loss improved from 1.38945 to 1.38230, saving model to model-1.38.h5
# Epoch 18/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.3042 - dice_coefficient: 0.5393 - val_loss: 1.3769 - val_dice_coefficient: 0.5202
#
# Epoch 00018: val_loss improved from 1.38230 to 1.37686, saving model to model-1.38.h5
# Epoch 19/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.2944 - dice_coefficient: 0.5420 - val_loss: 1.3703 - val_dice_coefficient: 0.5237
#
# Epoch 00019: val_loss improved from 1.37686 to 1.37033, saving model to model-1.37.h5
# Epoch 20/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.2932 - dice_coefficient: 0.5416 - val_loss: 1.3645 - val_dice_coefficient: 0.5257
#
# Epoch 00020: val_loss improved from 1.37033 to 1.36451, saving model to model-1.36.h5
# Epoch 21/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.2716 - dice_coefficient: 0.5473 - val_loss: 1.3596 - val_dice_coefficient: 0.5262
#
# Epoch 00021: val_loss improved from 1.36451 to 1.35959, saving model to model-1.36.h5
# Epoch 22/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.2392 - dice_coefficient: 0.5580 - val_loss: 1.3545 - val_dice_coefficient: 0.5289
#
# Epoch 00022: val_loss improved from 1.35959 to 1.35449, saving model to model-1.35.h5
# Epoch 23/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.2729 - dice_coefficient: 0.5480 - val_loss: 1.3501 - val_dice_coefficient: 0.5300
#
# Epoch 00023: val_loss improved from 1.35449 to 1.35010, saving model to model-1.35.h5
# Epoch 24/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.2558 - dice_coefficient: 0.5524 - val_loss: 1.3456 - val_dice_coefficient: 0.5316
#
# Epoch 00024: val_loss improved from 1.35010 to 1.34563, saving model to model-1.35.h5
# Epoch 25/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.2529 - dice_coefficient: 0.5536 - val_loss: 1.3411 - val_dice_coefficient: 0.5341
#
# Epoch 00025: val_loss improved from 1.34563 to 1.34112, saving model to model-1.34.h5
# Epoch 26/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.2429 - dice_coefficient: 0.5609 - val_loss: 1.3384 - val_dice_coefficient: 0.5322
#
# Epoch 00026: val_loss improved from 1.34112 to 1.33843, saving model to model-1.34.h5
# Epoch 27/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.1914 - dice_coefficient: 0.5763 - val_loss: 1.3340 - val_dice_coefficient: 0.5360
#
# Epoch 00027: val_loss improved from 1.33843 to 1.33395, saving model to model-1.33.h5
# Epoch 28/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.2228 - dice_coefficient: 0.5670 - val_loss: 1.3300 - val_dice_coefficient: 0.5377
#
# Epoch 00028: val_loss improved from 1.33395 to 1.33005, saving model to model-1.33.h5
# Epoch 29/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.2161 - dice_coefficient: 0.5647 - val_loss: 1.3270 - val_dice_coefficient: 0.5371
#
# Epoch 00029: val_loss improved from 1.33005 to 1.32704, saving model to model-1.33.h5
# Epoch 30/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.2049 - dice_coefficient: 0.5699 - val_loss: 1.3235 - val_dice_coefficient: 0.5393
#
# Epoch 00030: val_loss improved from 1.32704 to 1.32349, saving model to model-1.32.h5
# Epoch 31/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.2065 - dice_coefficient: 0.5683 - val_loss: 1.3201 - val_dice_coefficient: 0.5416
#
# Epoch 00031: val_loss improved from 1.32349 to 1.32010, saving model to model-1.32.h5
# Epoch 32/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.2067 - dice_coefficient: 0.5686 - val_loss: 1.3173 - val_dice_coefficient: 0.5402
#
# Epoch 00032: val_loss improved from 1.32010 to 1.31726, saving model to model-1.32.h5
# Epoch 33/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1828 - dice_coefficient: 0.5733 - val_loss: 1.3142 - val_dice_coefficient: 0.5421
#
# Epoch 00033: val_loss improved from 1.31726 to 1.31419, saving model to model-1.31.h5
# Epoch 34/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.1887 - dice_coefficient: 0.5731 - val_loss: 1.3112 - val_dice_coefficient: 0.5436
#
# Epoch 00034: val_loss improved from 1.31419 to 1.31122, saving model to model-1.31.h5
# Epoch 35/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1754 - dice_coefficient: 0.5720 - val_loss: 1.3094 - val_dice_coefficient: 0.5410
#
# Epoch 00035: val_loss improved from 1.31122 to 1.30940, saving model to model-1.31.h5
# Epoch 36/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1814 - dice_coefficient: 0.5782 - val_loss: 1.3059 - val_dice_coefficient: 0.5453
#
# Epoch 00036: val_loss improved from 1.30940 to 1.30586, saving model to model-1.31.h5
# Epoch 37/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.2010 - dice_coefficient: 0.5647 - val_loss: 1.3031 - val_dice_coefficient: 0.5455
#
# Epoch 00037: val_loss improved from 1.30586 to 1.30313, saving model to model-1.30.h5
# Epoch 38/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1673 - dice_coefficient: 0.5752 - val_loss: 1.3013 - val_dice_coefficient: 0.5441
#
# Epoch 00038: val_loss improved from 1.30313 to 1.30131, saving model to model-1.30.h5
# Epoch 39/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.1842 - dice_coefficient: 0.5687 - val_loss: 1.2985 - val_dice_coefficient: 0.5487
#
# Epoch 00039: val_loss improved from 1.30131 to 1.29850, saving model to model-1.30.h5
# Epoch 40/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1725 - dice_coefficient: 0.5813 - val_loss: 1.2962 - val_dice_coefficient: 0.5478
#
# Epoch 00040: val_loss improved from 1.29850 to 1.29622, saving model to model-1.30.h5
# Epoch 41/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1764 - dice_coefficient: 0.5719 - val_loss: 1.2944 - val_dice_coefficient: 0.5466
#
# Epoch 00041: val_loss improved from 1.29622 to 1.29436, saving model to model-1.29.h5
# Epoch 42/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1499 - dice_coefficient: 0.5853 - val_loss: 1.2916 - val_dice_coefficient: 0.5488
#
# Epoch 00042: val_loss improved from 1.29436 to 1.29162, saving model to model-1.29.h5
# Epoch 43/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.1741 - dice_coefficient: 0.5732 - val_loss: 1.2893 - val_dice_coefficient: 0.5496
#
# Epoch 00043: val_loss improved from 1.29162 to 1.28933, saving model to model-1.29.h5
# Epoch 44/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1558 - dice_coefficient: 0.5782 - val_loss: 1.2872 - val_dice_coefficient: 0.5506
#
# Epoch 00044: val_loss improved from 1.28933 to 1.28723, saving model to model-1.29.h5
# Epoch 45/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1363 - dice_coefficient: 0.5858 - val_loss: 1.2857 - val_dice_coefficient: 0.5488
#
# Epoch 00045: val_loss improved from 1.28723 to 1.28566, saving model to model-1.29.h5
# Epoch 46/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.1521 - dice_coefficient: 0.5839 - val_loss: 1.2833 - val_dice_coefficient: 0.5526
#
# Epoch 00046: val_loss improved from 1.28566 to 1.28331, saving model to model-1.28.h5
# Epoch 47/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1404 - dice_coefficient: 0.5891 - val_loss: 1.2812 - val_dice_coefficient: 0.5521
#
# Epoch 00047: val_loss improved from 1.28331 to 1.28124, saving model to model-1.28.h5
# Epoch 48/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1366 - dice_coefficient: 0.5888 - val_loss: 1.2791 - val_dice_coefficient: 0.5532
#
# Epoch 00048: val_loss improved from 1.28124 to 1.27914, saving model to model-1.28.h5
# Epoch 49/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.1432 - dice_coefficient: 0.5831 - val_loss: 1.2774 - val_dice_coefficient: 0.5516
#
# Epoch 00049: val_loss improved from 1.27914 to 1.27741, saving model to model-1.28.h5
# Epoch 50/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1207 - dice_coefficient: 0.5933 - val_loss: 1.2752 - val_dice_coefficient: 0.5540
#
# Epoch 00050: val_loss improved from 1.27741 to 1.27518, saving model to model-1.28.h5
# Epoch 51/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.1229 - dice_coefficient: 0.5867 - val_loss: 1.2733 - val_dice_coefficient: 0.5539
#
# Epoch 00051: val_loss improved from 1.27518 to 1.27335, saving model to model-1.27.h5
# Epoch 52/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1220 - dice_coefficient: 0.5895 - val_loss: 1.2716 - val_dice_coefficient: 0.5535
#
# Epoch 00052: val_loss improved from 1.27335 to 1.27158, saving model to model-1.27.h5
# Epoch 53/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1475 - dice_coefficient: 0.5760 - val_loss: 1.2705 - val_dice_coefficient: 0.5525
#
# Epoch 00053: val_loss improved from 1.27158 to 1.27047, saving model to model-1.27.h5
# Epoch 54/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0985 - dice_coefficient: 0.5991 - val_loss: 1.2683 - val_dice_coefficient: 0.5579
#
# Epoch 00054: val_loss improved from 1.27047 to 1.26827, saving model to model-1.27.h5
# Epoch 55/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1281 - dice_coefficient: 0.5866 - val_loss: 1.2667 - val_dice_coefficient: 0.5573
#
# Epoch 00055: val_loss improved from 1.26827 to 1.26666, saving model to model-1.27.h5
# Epoch 56/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.1084 - dice_coefficient: 0.5895 - val_loss: 1.2664 - val_dice_coefficient: 0.5521
#
# Epoch 00056: val_loss improved from 1.26666 to 1.26635, saving model to model-1.27.h5
# Epoch 57/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.0903 - dice_coefficient: 0.6005 - val_loss: 1.2630 - val_dice_coefficient: 0.5586
#
# Epoch 00057: val_loss improved from 1.26635 to 1.26300, saving model to model-1.26.h5
# Epoch 58/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0959 - dice_coefficient: 0.5933 - val_loss: 1.2615 - val_dice_coefficient: 0.5592
#
# Epoch 00058: val_loss improved from 1.26300 to 1.26145, saving model to model-1.26.h5
# Epoch 59/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.0844 - dice_coefficient: 0.5996 - val_loss: 1.2607 - val_dice_coefficient: 0.5553
#
# Epoch 00059: val_loss improved from 1.26145 to 1.26068, saving model to model-1.26.h5
# Epoch 60/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1013 - dice_coefficient: 0.5938 - val_loss: 1.2585 - val_dice_coefficient: 0.5577
#
# Epoch 00060: val_loss improved from 1.26068 to 1.25853, saving model to model-1.26.h5
# Epoch 61/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.0951 - dice_coefficient: 0.5940 - val_loss: 1.2569 - val_dice_coefficient: 0.5599
#
# Epoch 00061: val_loss improved from 1.25853 to 1.25692, saving model to model-1.26.h5
# Epoch 62/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0980 - dice_coefficient: 0.5947 - val_loss: 1.2562 - val_dice_coefficient: 0.5567
#
# Epoch 00062: val_loss improved from 1.25692 to 1.25617, saving model to model-1.26.h5
# Epoch 63/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.1087 - dice_coefficient: 0.5899 - val_loss: 1.2545 - val_dice_coefficient: 0.5580
#
# Epoch 00063: val_loss improved from 1.25617 to 1.25446, saving model to model-1.25.h5
# Epoch 64/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.1000 - dice_coefficient: 0.5934 - val_loss: 1.2526 - val_dice_coefficient: 0.5599
#
# Epoch 00064: val_loss improved from 1.25446 to 1.25255, saving model to model-1.25.h5
# Epoch 65/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0776 - dice_coefficient: 0.6047 - val_loss: 1.2514 - val_dice_coefficient: 0.5599
#
# Epoch 00065: val_loss improved from 1.25255 to 1.25138, saving model to model-1.25.h5
# Epoch 66/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0633 - dice_coefficient: 0.6102 - val_loss: 1.2503 - val_dice_coefficient: 0.5589
#
# Epoch 00066: val_loss improved from 1.25138 to 1.25027, saving model to model-1.25.h5
# Epoch 67/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.0921 - dice_coefficient: 0.5913 - val_loss: 1.2485 - val_dice_coefficient: 0.5604
#
# Epoch 00067: val_loss improved from 1.25027 to 1.24853, saving model to model-1.25.h5
# Epoch 68/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.1016 - dice_coefficient: 0.5890 - val_loss: 1.2471 - val_dice_coefficient: 0.5612
#
# Epoch 00068: val_loss improved from 1.24853 to 1.24712, saving model to model-1.25.h5
# Epoch 69/300
# 10/10 [==============================] - 0s 33ms/step - loss: 1.0782 - dice_coefficient: 0.5979 - val_loss: 1.2460 - val_dice_coefficient: 0.5620
#
# Epoch 00069: val_loss improved from 1.24712 to 1.24595, saving model to model-1.25.h5
# Epoch 70/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0899 - dice_coefficient: 0.5935 - val_loss: 1.2446 - val_dice_coefficient: 0.5614
#
# Epoch 00070: val_loss improved from 1.24595 to 1.24462, saving model to model-1.24.h5
# Epoch 71/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0556 - dice_coefficient: 0.6064 - val_loss: 1.2433 - val_dice_coefficient: 0.5614
#
# Epoch 00071: val_loss improved from 1.24462 to 1.24330, saving model to model-1.24.h5
# Epoch 72/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0727 - dice_coefficient: 0.5983 - val_loss: 1.2417 - val_dice_coefficient: 0.5629
#
# Epoch 00072: val_loss improved from 1.24330 to 1.24169, saving model to model-1.24.h5
# Epoch 73/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0560 - dice_coefficient: 0.6067 - val_loss: 1.2404 - val_dice_coefficient: 0.5629
#
# Epoch 00073: val_loss improved from 1.24169 to 1.24042, saving model to model-1.24.h5
# Epoch 74/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0580 - dice_coefficient: 0.6058 - val_loss: 1.2394 - val_dice_coefficient: 0.5620
#
# Epoch 00074: val_loss improved from 1.24042 to 1.23944, saving model to model-1.24.h5
# Epoch 75/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0608 - dice_coefficient: 0.6056 - val_loss: 1.2379 - val_dice_coefficient: 0.5652
#
# Epoch 00075: val_loss improved from 1.23944 to 1.23790, saving model to model-1.24.h5
# Epoch 76/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0688 - dice_coefficient: 0.6051 - val_loss: 1.2371 - val_dice_coefficient: 0.5624
#
# Epoch 00076: val_loss improved from 1.23790 to 1.23707, saving model to model-1.24.h5
# Epoch 77/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0685 - dice_coefficient: 0.6004 - val_loss: 1.2354 - val_dice_coefficient: 0.5652
#
# Epoch 00077: val_loss improved from 1.23707 to 1.23543, saving model to model-1.24.h5
# Epoch 78/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.0615 - dice_coefficient: 0.6013 - val_loss: 1.2346 - val_dice_coefficient: 0.5633
#
# Epoch 00078: val_loss improved from 1.23543 to 1.23465, saving model to model-1.23.h5
# Epoch 79/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.0559 - dice_coefficient: 0.6078 - val_loss: 1.2333 - val_dice_coefficient: 0.5659
#
# Epoch 00079: val_loss improved from 1.23465 to 1.23335, saving model to model-1.23.h5
# Epoch 80/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0340 - dice_coefficient: 0.6138 - val_loss: 1.2325 - val_dice_coefficient: 0.5641
#
# Epoch 00080: val_loss improved from 1.23335 to 1.23254, saving model to model-1.23.h5
# Epoch 81/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.0553 - dice_coefficient: 0.6044 - val_loss: 1.2315 - val_dice_coefficient: 0.5643
#
# Epoch 00081: val_loss improved from 1.23254 to 1.23153, saving model to model-1.23.h5
# Epoch 82/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.0535 - dice_coefficient: 0.6067 - val_loss: 1.2303 - val_dice_coefficient: 0.5651
#
# Epoch 00082: val_loss improved from 1.23153 to 1.23025, saving model to model-1.23.h5
# Epoch 83/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.0371 - dice_coefficient: 0.6128 - val_loss: 1.2290 - val_dice_coefficient: 0.5666
#
# Epoch 00083: val_loss improved from 1.23025 to 1.22905, saving model to model-1.23.h5
# Epoch 84/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0436 - dice_coefficient: 0.6113 - val_loss: 1.2285 - val_dice_coefficient: 0.5649
#
# Epoch 00084: val_loss improved from 1.22905 to 1.22849, saving model to model-1.23.h5
# Epoch 85/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.0446 - dice_coefficient: 0.6033 - val_loss: 1.2269 - val_dice_coefficient: 0.5675
#
# Epoch 00085: val_loss improved from 1.22849 to 1.22688, saving model to model-1.23.h5
# Epoch 86/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0716 - dice_coefficient: 0.5955 - val_loss: 1.2258 - val_dice_coefficient: 0.5665
#
# Epoch 00086: val_loss improved from 1.22688 to 1.22583, saving model to model-1.23.h5
# Epoch 87/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.0412 - dice_coefficient: 0.6074 - val_loss: 1.2248 - val_dice_coefficient: 0.5682
#
# Epoch 00087: val_loss improved from 1.22583 to 1.22478, saving model to model-1.22.h5
# Epoch 88/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0361 - dice_coefficient: 0.6115 - val_loss: 1.2242 - val_dice_coefficient: 0.5665
#
# Epoch 00088: val_loss improved from 1.22478 to 1.22421, saving model to model-1.22.h5
# Epoch 89/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0601 - dice_coefficient: 0.6017 - val_loss: 1.2228 - val_dice_coefficient: 0.5676
#
# Epoch 00089: val_loss improved from 1.22421 to 1.22285, saving model to model-1.22.h5
# Epoch 90/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0061 - dice_coefficient: 0.6238 - val_loss: 1.2217 - val_dice_coefficient: 0.5684
#
# Epoch 00090: val_loss improved from 1.22285 to 1.22171, saving model to model-1.22.h5
# Epoch 91/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.0240 - dice_coefficient: 0.6168 - val_loss: 1.2211 - val_dice_coefficient: 0.5670
#
# Epoch 00091: val_loss improved from 1.22171 to 1.22114, saving model to model-1.22.h5
# Epoch 92/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0302 - dice_coefficient: 0.6120 - val_loss: 1.2199 - val_dice_coefficient: 0.5686
#
# Epoch 00092: val_loss improved from 1.22114 to 1.21986, saving model to model-1.22.h5
# Epoch 93/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.0286 - dice_coefficient: 0.6167 - val_loss: 1.2188 - val_dice_coefficient: 0.5681
#
# Epoch 00093: val_loss improved from 1.21986 to 1.21880, saving model to model-1.22.h5
# Epoch 94/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0436 - dice_coefficient: 0.6077 - val_loss: 1.2180 - val_dice_coefficient: 0.5694
#
# Epoch 00094: val_loss improved from 1.21880 to 1.21798, saving model to model-1.22.h5
# Epoch 95/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0376 - dice_coefficient: 0.6124 - val_loss: 1.2171 - val_dice_coefficient: 0.5696
#
# Epoch 00095: val_loss improved from 1.21798 to 1.21711, saving model to model-1.22.h5
# Epoch 96/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.0072 - dice_coefficient: 0.6213 - val_loss: 1.2164 - val_dice_coefficient: 0.5690
#
# Epoch 00096: val_loss improved from 1.21711 to 1.21639, saving model to model-1.22.h5
# Epoch 97/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0205 - dice_coefficient: 0.6184 - val_loss: 1.2152 - val_dice_coefficient: 0.5703
#
# Epoch 00097: val_loss improved from 1.21639 to 1.21523, saving model to model-1.22.h5
# Epoch 98/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0265 - dice_coefficient: 0.6118 - val_loss: 1.2143 - val_dice_coefficient: 0.5693
#
# Epoch 00098: val_loss improved from 1.21523 to 1.21430, saving model to model-1.21.h5
# Epoch 99/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0060 - dice_coefficient: 0.6174 - val_loss: 1.2132 - val_dice_coefficient: 0.5712
#
# Epoch 00099: val_loss improved from 1.21430 to 1.21319, saving model to model-1.21.h5
# Epoch 100/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0222 - dice_coefficient: 0.6157 - val_loss: 1.2128 - val_dice_coefficient: 0.5688
#
# Epoch 00100: val_loss improved from 1.21319 to 1.21281, saving model to model-1.21.h5
# Epoch 101/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0142 - dice_coefficient: 0.6189 - val_loss: 1.2118 - val_dice_coefficient: 0.5742
#
# Epoch 00101: val_loss improved from 1.21281 to 1.21176, saving model to model-1.21.h5
# Epoch 102/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0035 - dice_coefficient: 0.6210 - val_loss: 1.2119 - val_dice_coefficient: 0.5676
#
# Epoch 00102: val_loss did not improve from 1.21176
# Epoch 103/300
# 10/10 [==============================] - 0s 30ms/step - loss: 1.0223 - dice_coefficient: 0.6086 - val_loss: 1.2098 - val_dice_coefficient: 0.5714
#
# Epoch 00103: val_loss improved from 1.21176 to 1.20984, saving model to model-1.21.h5
# Epoch 104/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9845 - dice_coefficient: 0.6287 - val_loss: 1.2095 - val_dice_coefficient: 0.5740
#
# Epoch 00104: val_loss improved from 1.20984 to 1.20947, saving model to model-1.21.h5
# Epoch 105/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.0138 - dice_coefficient: 0.6133 - val_loss: 1.2090 - val_dice_coefficient: 0.5694
#
# Epoch 00105: val_loss improved from 1.20947 to 1.20897, saving model to model-1.21.h5
# Epoch 106/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0267 - dice_coefficient: 0.6112 - val_loss: 1.2077 - val_dice_coefficient: 0.5705
#
# Epoch 00106: val_loss improved from 1.20897 to 1.20771, saving model to model-1.21.h5
# Epoch 107/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0241 - dice_coefficient: 0.6095 - val_loss: 1.2069 - val_dice_coefficient: 0.5743
#
# Epoch 00107: val_loss improved from 1.20771 to 1.20689, saving model to model-1.21.h5
# Epoch 108/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0055 - dice_coefficient: 0.6238 - val_loss: 1.2061 - val_dice_coefficient: 0.5729
#
# Epoch 00108: val_loss improved from 1.20689 to 1.20612, saving model to model-1.21.h5
# Epoch 109/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9919 - dice_coefficient: 0.6244 - val_loss: 1.2054 - val_dice_coefficient: 0.5719
#
# Epoch 00109: val_loss improved from 1.20612 to 1.20543, saving model to model-1.21.h5
# Epoch 110/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9921 - dice_coefficient: 0.6253 - val_loss: 1.2044 - val_dice_coefficient: 0.5732
#
# Epoch 00110: val_loss improved from 1.20543 to 1.20435, saving model to model-1.20.h5
# Epoch 111/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9878 - dice_coefficient: 0.6286 - val_loss: 1.2041 - val_dice_coefficient: 0.5719
#
# Epoch 00111: val_loss improved from 1.20435 to 1.20406, saving model to model-1.20.h5
# Epoch 112/300
# 10/10 [==============================] - 0s 31ms/step - loss: 1.0078 - dice_coefficient: 0.6138 - val_loss: 1.2030 - val_dice_coefficient: 0.5730
#
# Epoch 00112: val_loss improved from 1.20406 to 1.20296, saving model to model-1.20.h5
# Epoch 113/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9959 - dice_coefficient: 0.6224 - val_loss: 1.2022 - val_dice_coefficient: 0.5736
#
# Epoch 00113: val_loss improved from 1.20296 to 1.20217, saving model to model-1.20.h5
# Epoch 114/300
# 10/10 [==============================] - 0s 30ms/step - loss: 0.9967 - dice_coefficient: 0.6166 - val_loss: 1.2014 - val_dice_coefficient: 0.5731
#
# Epoch 00114: val_loss improved from 1.20217 to 1.20135, saving model to model-1.20.h5
# Epoch 115/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9877 - dice_coefficient: 0.6266 - val_loss: 1.2007 - val_dice_coefficient: 0.5733
#
# Epoch 00115: val_loss improved from 1.20135 to 1.20072, saving model to model-1.20.h5
# Epoch 116/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9940 - dice_coefficient: 0.6226 - val_loss: 1.2001 - val_dice_coefficient: 0.5748
#
# Epoch 00116: val_loss improved from 1.20072 to 1.20009, saving model to model-1.20.h5
# Epoch 117/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.0037 - dice_coefficient: 0.6141 - val_loss: 1.2000 - val_dice_coefficient: 0.5719
#
# Epoch 00117: val_loss improved from 1.20009 to 1.19995, saving model to model-1.20.h5
# Epoch 118/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9861 - dice_coefficient: 0.6238 - val_loss: 1.1990 - val_dice_coefficient: 0.5776
#
# Epoch 00118: val_loss improved from 1.19995 to 1.19905, saving model to model-1.20.h5
# Epoch 119/300
# 10/10 [==============================] - 0s 32ms/step - loss: 1.0066 - dice_coefficient: 0.6194 - val_loss: 1.1981 - val_dice_coefficient: 0.5742
#
# Epoch 00119: val_loss improved from 1.19905 to 1.19812, saving model to model-1.20.h5
# Epoch 120/300
# 10/10 [==============================] - 0s 30ms/step - loss: 0.9949 - dice_coefficient: 0.6214 - val_loss: 1.1972 - val_dice_coefficient: 0.5749
#
# Epoch 00120: val_loss improved from 1.19812 to 1.19723, saving model to model-1.20.h5
# Epoch 121/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9871 - dice_coefficient: 0.6265 - val_loss: 1.1964 - val_dice_coefficient: 0.5747
#
# Epoch 00121: val_loss improved from 1.19723 to 1.19642, saving model to model-1.20.h5
# Epoch 122/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9967 - dice_coefficient: 0.6208 - val_loss: 1.1958 - val_dice_coefficient: 0.5761
#
# Epoch 00122: val_loss improved from 1.19642 to 1.19582, saving model to model-1.20.h5
# Epoch 123/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9678 - dice_coefficient: 0.6355 - val_loss: 1.1952 - val_dice_coefficient: 0.5756
#
# Epoch 00123: val_loss improved from 1.19582 to 1.19517, saving model to model-1.20.h5
# Epoch 124/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9787 - dice_coefficient: 0.6278 - val_loss: 1.1950 - val_dice_coefficient: 0.5745
#
# Epoch 00124: val_loss improved from 1.19517 to 1.19498, saving model to model-1.19.h5
# Epoch 125/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9855 - dice_coefficient: 0.6270 - val_loss: 1.1941 - val_dice_coefficient: 0.5757
#
# Epoch 00125: val_loss improved from 1.19498 to 1.19407, saving model to model-1.19.h5
# Epoch 126/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9913 - dice_coefficient: 0.6247 - val_loss: 1.1933 - val_dice_coefficient: 0.5766
#
# Epoch 00126: val_loss improved from 1.19407 to 1.19327, saving model to model-1.19.h5
# Epoch 127/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9934 - dice_coefficient: 0.6221 - val_loss: 1.1928 - val_dice_coefficient: 0.5753
#
# Epoch 00127: val_loss improved from 1.19327 to 1.19281, saving model to model-1.19.h5
# Epoch 128/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9896 - dice_coefficient: 0.6193 - val_loss: 1.1921 - val_dice_coefficient: 0.5772
#
# Epoch 00128: val_loss improved from 1.19281 to 1.19210, saving model to model-1.19.h5
# Epoch 129/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9889 - dice_coefficient: 0.6266 - val_loss: 1.1916 - val_dice_coefficient: 0.5759
#
# Epoch 00129: val_loss improved from 1.19210 to 1.19162, saving model to model-1.19.h5
# Epoch 130/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9792 - dice_coefficient: 0.6252 - val_loss: 1.1908 - val_dice_coefficient: 0.5761
#
# Epoch 00130: val_loss improved from 1.19162 to 1.19081, saving model to model-1.19.h5
# Epoch 131/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9848 - dice_coefficient: 0.6266 - val_loss: 1.1898 - val_dice_coefficient: 0.5771
#
# Epoch 00131: val_loss improved from 1.19081 to 1.18984, saving model to model-1.19.h5
# Epoch 132/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9854 - dice_coefficient: 0.6250 - val_loss: 1.1893 - val_dice_coefficient: 0.5772
#
# Epoch 00132: val_loss improved from 1.18984 to 1.18934, saving model to model-1.19.h5
# Epoch 133/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9744 - dice_coefficient: 0.6262 - val_loss: 1.1890 - val_dice_coefficient: 0.5766
#
# Epoch 00133: val_loss improved from 1.18934 to 1.18905, saving model to model-1.19.h5
# Epoch 134/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9781 - dice_coefficient: 0.6258 - val_loss: 1.1883 - val_dice_coefficient: 0.5789
#
# Epoch 00134: val_loss improved from 1.18905 to 1.18834, saving model to model-1.19.h5
# Epoch 135/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9656 - dice_coefficient: 0.6322 - val_loss: 1.1878 - val_dice_coefficient: 0.5776
#
# Epoch 00135: val_loss improved from 1.18834 to 1.18779, saving model to model-1.19.h5
# Epoch 136/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9733 - dice_coefficient: 0.6285 - val_loss: 1.1879 - val_dice_coefficient: 0.5755
#
# Epoch 00136: val_loss did not improve from 1.18779
# Epoch 137/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9761 - dice_coefficient: 0.6272 - val_loss: 1.1865 - val_dice_coefficient: 0.5797
#
# Epoch 00137: val_loss improved from 1.18779 to 1.18651, saving model to model-1.19.h5
# Epoch 138/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9747 - dice_coefficient: 0.6257 - val_loss: 1.1865 - val_dice_coefficient: 0.5774
#
# Epoch 00138: val_loss improved from 1.18651 to 1.18645, saving model to model-1.19.h5
# Epoch 139/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9811 - dice_coefficient: 0.6220 - val_loss: 1.1862 - val_dice_coefficient: 0.5774
#
# Epoch 00139: val_loss improved from 1.18645 to 1.18620, saving model to model-1.19.h5
# Epoch 140/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9765 - dice_coefficient: 0.6242 - val_loss: 1.1850 - val_dice_coefficient: 0.5804
#
# Epoch 00140: val_loss improved from 1.18620 to 1.18501, saving model to model-1.19.h5
# Epoch 141/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9592 - dice_coefficient: 0.6354 - val_loss: 1.1850 - val_dice_coefficient: 0.5776
#
# Epoch 00141: val_loss improved from 1.18501 to 1.18501, saving model to model-1.19.h5
# Epoch 142/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9933 - dice_coefficient: 0.6185 - val_loss: 1.1844 - val_dice_coefficient: 0.5781
#
# Epoch 00142: val_loss improved from 1.18501 to 1.18443, saving model to model-1.18.h5
# Epoch 143/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9788 - dice_coefficient: 0.6258 - val_loss: 1.1836 - val_dice_coefficient: 0.5792
#
# Epoch 00143: val_loss improved from 1.18443 to 1.18360, saving model to model-1.18.h5
# Epoch 144/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9418 - dice_coefficient: 0.6411 - val_loss: 1.1830 - val_dice_coefficient: 0.5792
#
# Epoch 00144: val_loss improved from 1.18360 to 1.18302, saving model to model-1.18.h5
# Epoch 145/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9517 - dice_coefficient: 0.6331 - val_loss: 1.1830 - val_dice_coefficient: 0.5775
#
# Epoch 00145: val_loss improved from 1.18302 to 1.18300, saving model to model-1.18.h5
# Epoch 146/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9565 - dice_coefficient: 0.6353 - val_loss: 1.1822 - val_dice_coefficient: 0.5796
#
# Epoch 00146: val_loss improved from 1.18300 to 1.18224, saving model to model-1.18.h5
# Epoch 147/300
# 10/10 [==============================] - 0s 33ms/step - loss: 0.9510 - dice_coefficient: 0.6364 - val_loss: 1.1818 - val_dice_coefficient: 0.5785
#
# Epoch 00147: val_loss improved from 1.18224 to 1.18179, saving model to model-1.18.h5
# Epoch 148/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9677 - dice_coefficient: 0.6259 - val_loss: 1.1811 - val_dice_coefficient: 0.5798
#
# Epoch 00148: val_loss improved from 1.18179 to 1.18113, saving model to model-1.18.h5
# Epoch 149/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9712 - dice_coefficient: 0.6262 - val_loss: 1.1807 - val_dice_coefficient: 0.5801
#
# Epoch 00149: val_loss improved from 1.18113 to 1.18068, saving model to model-1.18.h5
# Epoch 150/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9680 - dice_coefficient: 0.6266 - val_loss: 1.1800 - val_dice_coefficient: 0.5808
#
# Epoch 00150: val_loss improved from 1.18068 to 1.18003, saving model to model-1.18.h5
# Epoch 151/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9379 - dice_coefficient: 0.6360 - val_loss: 1.1802 - val_dice_coefficient: 0.5788
#
# Epoch 00151: val_loss did not improve from 1.18003
# Epoch 152/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9652 - dice_coefficient: 0.6255 - val_loss: 1.1794 - val_dice_coefficient: 0.5805
#
# Epoch 00152: val_loss improved from 1.18003 to 1.17940, saving model to model-1.18.h5
# Epoch 153/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9524 - dice_coefficient: 0.6381 - val_loss: 1.1788 - val_dice_coefficient: 0.5823
#
# Epoch 00153: val_loss improved from 1.17940 to 1.17879, saving model to model-1.18.h5
# Epoch 154/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9419 - dice_coefficient: 0.6416 - val_loss: 1.1783 - val_dice_coefficient: 0.5800
#
# Epoch 00154: val_loss improved from 1.17879 to 1.17827, saving model to model-1.18.h5
# Epoch 155/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9469 - dice_coefficient: 0.6366 - val_loss: 1.1780 - val_dice_coefficient: 0.5799
#
# Epoch 00155: val_loss improved from 1.17827 to 1.17803, saving model to model-1.18.h5
# Epoch 156/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9255 - dice_coefficient: 0.6424 - val_loss: 1.1773 - val_dice_coefficient: 0.5811
#
# Epoch 00156: val_loss improved from 1.17803 to 1.17726, saving model to model-1.18.h5
# Epoch 157/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9463 - dice_coefficient: 0.6357 - val_loss: 1.1769 - val_dice_coefficient: 0.5809
#
# Epoch 00157: val_loss improved from 1.17726 to 1.17687, saving model to model-1.18.h5
# Epoch 158/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9436 - dice_coefficient: 0.6394 - val_loss: 1.1768 - val_dice_coefficient: 0.5803
#
# Epoch 00158: val_loss improved from 1.17687 to 1.17676, saving model to model-1.18.h5
# Epoch 159/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9610 - dice_coefficient: 0.6357 - val_loss: 1.1764 - val_dice_coefficient: 0.5813
#
# Epoch 00159: val_loss improved from 1.17676 to 1.17639, saving model to model-1.18.h5
# Epoch 160/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9411 - dice_coefficient: 0.6384 - val_loss: 1.1763 - val_dice_coefficient: 0.5807
#
# Epoch 00160: val_loss improved from 1.17639 to 1.17628, saving model to model-1.18.h5
# Epoch 161/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9460 - dice_coefficient: 0.6388 - val_loss: 1.1753 - val_dice_coefficient: 0.5822
#
# Epoch 00161: val_loss improved from 1.17628 to 1.17533, saving model to model-1.18.h5
# Epoch 162/300
# 10/10 [==============================] - 0s 33ms/step - loss: 0.9208 - dice_coefficient: 0.6490 - val_loss: 1.1752 - val_dice_coefficient: 0.5819
#
# Epoch 00162: val_loss improved from 1.17533 to 1.17515, saving model to model-1.18.h5
# Epoch 163/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9393 - dice_coefficient: 0.6374 - val_loss: 1.1759 - val_dice_coefficient: 0.5788
#
# Epoch 00163: val_loss did not improve from 1.17515
# Epoch 164/300
# 10/10 [==============================] - 0s 33ms/step - loss: 0.9286 - dice_coefficient: 0.6408 - val_loss: 1.1741 - val_dice_coefficient: 0.5829
#
# Epoch 00164: val_loss improved from 1.17515 to 1.17409, saving model to model-1.17.h5
# Epoch 165/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9223 - dice_coefficient: 0.6442 - val_loss: 1.1740 - val_dice_coefficient: 0.5823
#
# Epoch 00165: val_loss improved from 1.17409 to 1.17396, saving model to model-1.17.h5
# Epoch 166/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9288 - dice_coefficient: 0.6421 - val_loss: 1.1736 - val_dice_coefficient: 0.5823
#
# Epoch 00166: val_loss improved from 1.17396 to 1.17356, saving model to model-1.17.h5
# Epoch 167/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9194 - dice_coefficient: 0.6442 - val_loss: 1.1734 - val_dice_coefficient: 0.5826
#
# Epoch 00167: val_loss improved from 1.17356 to 1.17342, saving model to model-1.17.h5
# Epoch 168/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9358 - dice_coefficient: 0.6373 - val_loss: 1.1733 - val_dice_coefficient: 0.5813
#
# Epoch 00168: val_loss improved from 1.17342 to 1.17332, saving model to model-1.17.h5
# Epoch 169/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9372 - dice_coefficient: 0.6387 - val_loss: 1.1727 - val_dice_coefficient: 0.5825
#
# Epoch 00169: val_loss improved from 1.17332 to 1.17273, saving model to model-1.17.h5
# Epoch 170/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9408 - dice_coefficient: 0.6378 - val_loss: 1.1719 - val_dice_coefficient: 0.5841
#
# Epoch 00170: val_loss improved from 1.17273 to 1.17188, saving model to model-1.17.h5
# Epoch 171/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9401 - dice_coefficient: 0.6423 - val_loss: 1.1723 - val_dice_coefficient: 0.5812
#
# Epoch 00171: val_loss did not improve from 1.17188
# Epoch 172/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9297 - dice_coefficient: 0.6410 - val_loss: 1.1713 - val_dice_coefficient: 0.5841
#
# Epoch 00172: val_loss improved from 1.17188 to 1.17134, saving model to model-1.17.h5
# Epoch 173/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9193 - dice_coefficient: 0.6446 - val_loss: 1.1711 - val_dice_coefficient: 0.5832
#
# Epoch 00173: val_loss improved from 1.17134 to 1.17114, saving model to model-1.17.h5
# Epoch 174/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9338 - dice_coefficient: 0.6368 - val_loss: 1.1716 - val_dice_coefficient: 0.5809
#
# Epoch 00174: val_loss did not improve from 1.17114
# Epoch 175/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9248 - dice_coefficient: 0.6474 - val_loss: 1.1705 - val_dice_coefficient: 0.5865
#
# Epoch 00175: val_loss improved from 1.17114 to 1.17046, saving model to model-1.17.h5
# Epoch 176/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9212 - dice_coefficient: 0.6499 - val_loss: 1.1709 - val_dice_coefficient: 0.5814
#
# Epoch 00176: val_loss did not improve from 1.17046
# Epoch 177/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9405 - dice_coefficient: 0.6347 - val_loss: 1.1697 - val_dice_coefficient: 0.5830
#
# Epoch 00177: val_loss improved from 1.17046 to 1.16969, saving model to model-1.17.h5
# Epoch 178/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9199 - dice_coefficient: 0.6473 - val_loss: 1.1690 - val_dice_coefficient: 0.5852
#
# Epoch 00178: val_loss improved from 1.16969 to 1.16900, saving model to model-1.17.h5
# Epoch 179/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9236 - dice_coefficient: 0.6460 - val_loss: 1.1690 - val_dice_coefficient: 0.5841
#
# Epoch 00179: val_loss improved from 1.16900 to 1.16896, saving model to model-1.17.h5
# Epoch 180/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9191 - dice_coefficient: 0.6489 - val_loss: 1.1690 - val_dice_coefficient: 0.5831
#
# Epoch 00180: val_loss did not improve from 1.16896
# Epoch 181/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9397 - dice_coefficient: 0.6365 - val_loss: 1.1682 - val_dice_coefficient: 0.5852
#
# Epoch 00181: val_loss improved from 1.16896 to 1.16817, saving model to model-1.17.h5
# Epoch 182/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9093 - dice_coefficient: 0.6532 - val_loss: 1.1681 - val_dice_coefficient: 0.5866
#
# Epoch 00182: val_loss improved from 1.16817 to 1.16808, saving model to model-1.17.h5
# Epoch 183/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9415 - dice_coefficient: 0.6369 - val_loss: 1.1692 - val_dice_coefficient: 0.5811
#
# Epoch 00183: val_loss did not improve from 1.16808
# Epoch 184/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9351 - dice_coefficient: 0.6328 - val_loss: 1.1673 - val_dice_coefficient: 0.5849
#
# Epoch 00184: val_loss improved from 1.16808 to 1.16732, saving model to model-1.17.h5
# Epoch 185/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9340 - dice_coefficient: 0.6411 - val_loss: 1.1669 - val_dice_coefficient: 0.5871
#
# Epoch 00185: val_loss improved from 1.16732 to 1.16693, saving model to model-1.17.h5
# Epoch 186/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9341 - dice_coefficient: 0.6408 - val_loss: 1.1677 - val_dice_coefficient: 0.5826
#
# Epoch 00186: val_loss did not improve from 1.16693
# Epoch 187/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9399 - dice_coefficient: 0.6304 - val_loss: 1.1663 - val_dice_coefficient: 0.5857
#
# Epoch 00187: val_loss improved from 1.16693 to 1.16630, saving model to model-1.17.h5
# Epoch 188/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9410 - dice_coefficient: 0.6361 - val_loss: 1.1660 - val_dice_coefficient: 0.5854
#
# Epoch 00188: val_loss improved from 1.16630 to 1.16598, saving model to model-1.17.h5
# Epoch 189/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9200 - dice_coefficient: 0.6466 - val_loss: 1.1660 - val_dice_coefficient: 0.5846
#
# Epoch 00189: val_loss did not improve from 1.16598
# Epoch 190/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9188 - dice_coefficient: 0.6416 - val_loss: 1.1658 - val_dice_coefficient: 0.5858
#
# Epoch 00190: val_loss improved from 1.16598 to 1.16582, saving model to model-1.17.h5
# Epoch 191/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9349 - dice_coefficient: 0.6398 - val_loss: 1.1656 - val_dice_coefficient: 0.5848
#
# Epoch 00191: val_loss improved from 1.16582 to 1.16563, saving model to model-1.17.h5
# Epoch 192/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9162 - dice_coefficient: 0.6445 - val_loss: 1.1651 - val_dice_coefficient: 0.5858
#
# Epoch 00192: val_loss improved from 1.16563 to 1.16513, saving model to model-1.17.h5
# Epoch 193/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9038 - dice_coefficient: 0.6507 - val_loss: 1.1649 - val_dice_coefficient: 0.5866
#
# Epoch 00193: val_loss improved from 1.16513 to 1.16485, saving model to model-1.16.h5
# Epoch 194/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9258 - dice_coefficient: 0.6406 - val_loss: 1.1645 - val_dice_coefficient: 0.5861
#
# Epoch 00194: val_loss improved from 1.16485 to 1.16450, saving model to model-1.16.h5
# Epoch 195/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.9186 - dice_coefficient: 0.6451 - val_loss: 1.1642 - val_dice_coefficient: 0.5866
#
# Epoch 00195: val_loss improved from 1.16450 to 1.16419, saving model to model-1.16.h5
# Epoch 196/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9213 - dice_coefficient: 0.6469 - val_loss: 1.1646 - val_dice_coefficient: 0.5842
#
# Epoch 00196: val_loss did not improve from 1.16419
# Epoch 197/300
# ...
#
# Epoch 00230: val_loss improved from 1.15838 to 1.15835, saving model to model-1.16.h5
# Epoch 231/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.9120 - dice_coefficient: 0.6398 - val_loss: 1.1575 - val_dice_coefficient: 0.5911
#
# Epoch 00231: val_loss improved from 1.15835 to 1.15749, saving model to model-1.16.h5
# Epoch 232/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8905 - dice_coefficient: 0.6594 - val_loss: 1.1575 - val_dice_coefficient: 0.5894
#
# Epoch 00232: val_loss improved from 1.15749 to 1.15747, saving model to model-1.16.h5
# Epoch 233/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8905 - dice_coefficient: 0.6544 - val_loss: 1.1574 - val_dice_coefficient: 0.5888
#
# Epoch 00233: val_loss improved from 1.15747 to 1.15742, saving model to model-1.16.h5
# Epoch 234/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8894 - dice_coefficient: 0.6566 - val_loss: 1.1569 - val_dice_coefficient: 0.5913
#
# Epoch 00234: val_loss improved from 1.15742 to 1.15688, saving model to model-1.16.h5
# Epoch 235/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8918 - dice_coefficient: 0.6547 - val_loss: 1.1575 - val_dice_coefficient: 0.5878
#
# Epoch 00235: val_loss did not improve from 1.15688
# Epoch 236/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8889 - dice_coefficient: 0.6516 - val_loss: 1.1570 - val_dice_coefficient: 0.5896
#
# Epoch 00236: val_loss did not improve from 1.15688
# Epoch 237/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8917 - dice_coefficient: 0.6517 - val_loss: 1.1567 - val_dice_coefficient: 0.5898
#
# Epoch 00237: val_loss improved from 1.15688 to 1.15669, saving model to model-1.16.h5
# Epoch 238/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8918 - dice_coefficient: 0.6472 - val_loss: 1.1565 - val_dice_coefficient: 0.5896
#
# Epoch 00238: val_loss improved from 1.15669 to 1.15652, saving model to model-1.16.h5
# Epoch 239/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8890 - dice_coefficient: 0.6561 - val_loss: 1.1561 - val_dice_coefficient: 0.5917
#
# Epoch 00239: val_loss improved from 1.15652 to 1.15615, saving model to model-1.16.h5
# Epoch 240/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8938 - dice_coefficient: 0.6560 - val_loss: 1.1571 - val_dice_coefficient: 0.5884
#
# Epoch 00240: val_loss did not improve from 1.15615
# Epoch 241/300
# 10/10 [==============================] - 0s 30ms/step - loss: 0.8835 - dice_coefficient: 0.6546 - val_loss: 1.1565 - val_dice_coefficient: 0.5891
#
# Epoch 00241: val_loss did not improve from 1.15615
# Epoch 242/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8812 - dice_coefficient: 0.6588 - val_loss: 1.1561 - val_dice_coefficient: 0.5902
#
# Epoch 00242: val_loss improved from 1.15615 to 1.15612, saving model to model-1.16.h5
# Epoch 243/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8818 - dice_coefficient: 0.6580 - val_loss: 1.1559 - val_dice_coefficient: 0.5911
#
# Epoch 00243: val_loss improved from 1.15612 to 1.15594, saving model to model-1.16.h5
# Epoch 244/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8900 - dice_coefficient: 0.6592 - val_loss: 1.1559 - val_dice_coefficient: 0.5899
#
# Epoch 00244: val_loss improved from 1.15594 to 1.15588, saving model to model-1.16.h5
# Epoch 245/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8877 - dice_coefficient: 0.6521 - val_loss: 1.1565 - val_dice_coefficient: 0.5884
#
# Epoch 00245: val_loss did not improve from 1.15588
# Epoch 246/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8818 - dice_coefficient: 0.6611 - val_loss: 1.1555 - val_dice_coefficient: 0.5907
#
# Epoch 00246: val_loss improved from 1.15588 to 1.15553, saving model to model-1.16.h5
# Epoch 247/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8908 - dice_coefficient: 0.6511 - val_loss: 1.1555 - val_dice_coefficient: 0.5912
#
# Epoch 00247: val_loss improved from 1.15553 to 1.15549, saving model to model-1.16.h5
# Epoch 248/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8814 - dice_coefficient: 0.6562 - val_loss: 1.1558 - val_dice_coefficient: 0.5902
#
# Epoch 00248: val_loss did not improve from 1.15549
# Epoch 249/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8901 - dice_coefficient: 0.6511 - val_loss: 1.1556 - val_dice_coefficient: 0.5908
#
# Epoch 00249: val_loss did not improve from 1.15549
# Epoch 250/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8876 - dice_coefficient: 0.6560 - val_loss: 1.1555 - val_dice_coefficient: 0.5900
#
# Epoch 00250: val_loss improved from 1.15549 to 1.15546, saving model to model-1.16.h5
# Epoch 251/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8914 - dice_coefficient: 0.6538 - val_loss: 1.1550 - val_dice_coefficient: 0.5921
#
# Epoch 00251: val_loss improved from 1.15546 to 1.15497, saving model to model-1.15.h5
# Epoch 252/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8982 - dice_coefficient: 0.6541 - val_loss: 1.1553 - val_dice_coefficient: 0.5900
#
# Epoch 00252: val_loss did not improve from 1.15497
# Epoch 253/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8801 - dice_coefficient: 0.6594 - val_loss: 1.1550 - val_dice_coefficient: 0.5910
#
# Epoch 00253: val_loss did not improve from 1.15497
# Epoch 254/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8823 - dice_coefficient: 0.6549 - val_loss: 1.1550 - val_dice_coefficient: 0.5911
#
# Epoch 00254: val_loss improved from 1.15497 to 1.15496, saving model to model-1.15.h5
# Epoch 255/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8702 - dice_coefficient: 0.6668 - val_loss: 1.1548 - val_dice_coefficient: 0.5916
#
# Epoch 00255: val_loss improved from 1.15496 to 1.15480, saving model to model-1.15.h5
# Epoch 256/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8785 - dice_coefficient: 0.6596 - val_loss: 1.1550 - val_dice_coefficient: 0.5913
#
# Epoch 00256: val_loss did not improve from 1.15480
# Epoch 257/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8849 - dice_coefficient: 0.6544 - val_loss: 1.1559 - val_dice_coefficient: 0.5890
#
# Epoch 00257: val_loss did not improve from 1.15480
# Epoch 258/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8868 - dice_coefficient: 0.6551 - val_loss: 1.1549 - val_dice_coefficient: 0.5904
#
# Epoch 00258: val_loss did not improve from 1.15480
# Epoch 259/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8725 - dice_coefficient: 0.6644 - val_loss: 1.1543 - val_dice_coefficient: 0.5933
#
# Epoch 00259: val_loss improved from 1.15480 to 1.15431, saving model to model-1.15.h5
# Epoch 260/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8756 - dice_coefficient: 0.6603 - val_loss: 1.1549 - val_dice_coefficient: 0.5907
#
# Epoch 00260: val_loss did not improve from 1.15431
# Epoch 261/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8858 - dice_coefficient: 0.6572 - val_loss: 1.1545 - val_dice_coefficient: 0.5919
#
# Epoch 00261: val_loss did not improve from 1.15431
# Epoch 262/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8718 - dice_coefficient: 0.6607 - val_loss: 1.1543 - val_dice_coefficient: 0.5912
#
# Epoch 00262: val_loss did not improve from 1.15431
# Epoch 263/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8696 - dice_coefficient: 0.6655 - val_loss: 1.1541 - val_dice_coefficient: 0.5932
#
# Epoch 00263: val_loss improved from 1.15431 to 1.15413, saving model to model-1.15.h5
# Epoch 264/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8712 - dice_coefficient: 0.6630 - val_loss: 1.1551 - val_dice_coefficient: 0.5898
#
# Epoch 00264: val_loss did not improve from 1.15413
# Epoch 265/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8822 - dice_coefficient: 0.6543 - val_loss: 1.1540 - val_dice_coefficient: 0.5925
#
# Epoch 00265: val_loss improved from 1.15413 to 1.15396, saving model to model-1.15.h5
# Epoch 266/300
# 10/10 [==============================] - 0s 30ms/step - loss: 0.8846 - dice_coefficient: 0.6561 - val_loss: 1.1538 - val_dice_coefficient: 0.5923
#
# Epoch 00266: val_loss improved from 1.15396 to 1.15384, saving model to model-1.15.h5
# Epoch 267/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8725 - dice_coefficient: 0.6561 - val_loss: 1.1543 - val_dice_coefficient: 0.5913
#
# Epoch 00267: val_loss did not improve from 1.15384
# Epoch 268/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8787 - dice_coefficient: 0.6639 - val_loss: 1.1539 - val_dice_coefficient: 0.5926
#
# Epoch 00268: val_loss did not improve from 1.15384
# Epoch 269/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8709 - dice_coefficient: 0.6624 - val_loss: 1.1543 - val_dice_coefficient: 0.5912
#
# Epoch 00269: val_loss did not improve from 1.15384
# Epoch 270/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8812 - dice_coefficient: 0.6549 - val_loss: 1.1538 - val_dice_coefficient: 0.5923
#
# Epoch 00270: val_loss improved from 1.15384 to 1.15376, saving model to model-1.15.h5
# Epoch 271/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8768 - dice_coefficient: 0.6576 - val_loss: 1.1542 - val_dice_coefficient: 0.5906
#
# Epoch 00271: val_loss did not improve from 1.15376
# Epoch 272/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8765 - dice_coefficient: 0.6624 - val_loss: 1.1534 - val_dice_coefficient: 0.5933
#
# Epoch 00272: val_loss improved from 1.15376 to 1.15340, saving model to model-1.15.h5
# Epoch 273/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8747 - dice_coefficient: 0.6640 - val_loss: 1.1539 - val_dice_coefficient: 0.5917
#
# Epoch 00273: val_loss did not improve from 1.15340
# Epoch 274/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8665 - dice_coefficient: 0.6630 - val_loss: 1.1541 - val_dice_coefficient: 0.5908
#
# Epoch 00274: val_loss did not improve from 1.15340
# Epoch 275/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8714 - dice_coefficient: 0.6611 - val_loss: 1.1535 - val_dice_coefficient: 0.5935
#
# Epoch 00275: val_loss did not improve from 1.15340
# Epoch 276/300
# 10/10 [==============================] - 0s 33ms/step - loss: 0.8606 - dice_coefficient: 0.6638 - val_loss: 1.1541 - val_dice_coefficient: 0.5910
#
# Epoch 00276: val_loss did not improve from 1.15340
# Epoch 277/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8651 - dice_coefficient: 0.6604 - val_loss: 1.1537 - val_dice_coefficient: 0.5917
#
# Epoch 00277: val_loss did not improve from 1.15340
# Epoch 278/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8700 - dice_coefficient: 0.6651 - val_loss: 1.1533 - val_dice_coefficient: 0.5937
#
# Epoch 00278: val_loss improved from 1.15340 to 1.15326, saving model to model-1.15.h5
# Epoch 279/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8926 - dice_coefficient: 0.6546 - val_loss: 1.1537 - val_dice_coefficient: 0.5917
#
# Epoch 00279: val_loss did not improve from 1.15326
# Epoch 280/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8818 - dice_coefficient: 0.6565 - val_loss: 1.1542 - val_dice_coefficient: 0.5903
#
# Epoch 00280: val_loss did not improve from 1.15326
# Epoch 281/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8974 - dice_coefficient: 0.6504 - val_loss: 1.1534 - val_dice_coefficient: 0.5937
#
# Epoch 00281: val_loss did not improve from 1.15326
# Epoch 282/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8855 - dice_coefficient: 0.6545 - val_loss: 1.1531 - val_dice_coefficient: 0.5939
#
# Epoch 00282: val_loss improved from 1.15326 to 1.15311, saving model to model-1.15.h5
# Epoch 283/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8665 - dice_coefficient: 0.6674 - val_loss: 1.1540 - val_dice_coefficient: 0.5912
#
# Epoch 00283: val_loss did not improve from 1.15311
# Epoch 284/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8523 - dice_coefficient: 0.6691 - val_loss: 1.1532 - val_dice_coefficient: 0.5943
#
# Epoch 00284: val_loss did not improve from 1.15311
# Epoch 285/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8536 - dice_coefficient: 0.6713 - val_loss: 1.1534 - val_dice_coefficient: 0.5927
#
# Epoch 00285: val_loss did not improve from 1.15311
# Epoch 286/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8570 - dice_coefficient: 0.6649 - val_loss: 1.1536 - val_dice_coefficient: 0.5921
#
# Epoch 00286: val_loss did not improve from 1.15311
# Epoch 287/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8596 - dice_coefficient: 0.6708 - val_loss: 1.1533 - val_dice_coefficient: 0.5947
#
# Epoch 00287: val_loss did not improve from 1.15311
# Epoch 288/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8453 - dice_coefficient: 0.6678 - val_loss: 1.1539 - val_dice_coefficient: 0.5919
#
# Epoch 00288: val_loss did not improve from 1.15311
# Epoch 289/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8650 - dice_coefficient: 0.6650 - val_loss: 1.1536 - val_dice_coefficient: 0.5923
#
# Epoch 00289: val_loss did not improve from 1.15311
# Epoch 290/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8457 - dice_coefficient: 0.6718 - val_loss: 1.1531 - val_dice_coefficient: 0.5939
#
# Epoch 00290: val_loss improved from 1.15311 to 1.15306, saving model to model-1.15.h5
# Epoch 291/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8721 - dice_coefficient: 0.6607 - val_loss: 1.1533 - val_dice_coefficient: 0.5928
#
# Epoch 00291: val_loss did not improve from 1.15306
# Epoch 292/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8558 - dice_coefficient: 0.6641 - val_loss: 1.1534 - val_dice_coefficient: 0.5928
#
# Epoch 00292: val_loss did not improve from 1.15306
# Epoch 293/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8695 - dice_coefficient: 0.6621 - val_loss: 1.1533 - val_dice_coefficient: 0.5939
#
# Epoch 00293: val_loss did not improve from 1.15306
# Epoch 294/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8724 - dice_coefficient: 0.6626 - val_loss: 1.1531 - val_dice_coefficient: 0.5939
#
# Epoch 00294: val_loss did not improve from 1.15306
# Epoch 295/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8656 - dice_coefficient: 0.6625 - val_loss: 1.1536 - val_dice_coefficient: 0.5917
#
# Epoch 00295: val_loss did not improve from 1.15306
# Epoch 296/300
# 10/10 [==============================] - 0s 31ms/step - loss: 0.8800 - dice_coefficient: 0.6532 - val_loss: 1.1530 - val_dice_coefficient: 0.5936
#
# Epoch 00296: val_loss improved from 1.15306 to 1.15302, saving model to model-1.15.h5
# Epoch 297/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8737 - dice_coefficient: 0.6614 - val_loss: 1.1528 - val_dice_coefficient: 0.5955
#
# Epoch 00297: val_loss improved from 1.15302 to 1.15279, saving model to model-1.15.h5
# Epoch 298/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8724 - dice_coefficient: 0.6653 - val_loss: 1.1537 - val_dice_coefficient: 0.5922
#
# Epoch 00298: val_loss did not improve from 1.15279
# Epoch 299/300
# 10/10 [==============================] - 0s 32ms/step - loss: 0.8668 - dice_coefficient: 0.6622 - val_loss: 1.1535 - val_dice_coefficient: 0.5929
#
# Epoch 00299: val_loss did not improve from 1.15279
# Epoch 300/300
# 10/10 [==============================] - 0s 30ms/step - loss: 0.8584 - dice_coefficient: 0.6659 - val_loss: 1.1531 - val_dice_coefficient: 0.5944
#
# Epoch 00300: val_loss did not improve from 1.15279

# %% [markdown]
# ## Doing predictions on the model we trained

# %%
import matplotlib.pyplot as plt
filename = '/content/drive/MyDrive/glearn/ACV/raccoon-25_prediction_image.jpg'

unscaled = cv2.imread(filename)
image = cv2.resize(unscaled, (IMAGE_WIDTH, IMAGE_HEIGHT))
feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

pred_mask = cv2.resize(1.0*(model.predict(x=np.array([feat_scaled]))[0] > 0.5), (IMAGE_WIDTH,IMAGE_HEIGHT))

image2 = image
image2[:,:,0] = pred_mask*image[:,:,0]
image2[:,:,1] = pred_mask*image[:,:,1]
image2[:,:,2] = pred_mask*image[:,:,2]

out_image = image2

plt.imshow(out_image)

# %%
plt.imshow(feat_scaled)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import matplotlib.pyplot as plt
filename = '/content/drive/MyDrive/glearn/ACV/harry_1.jpg'

unscaled = cv2.imread(filename)
image = cv2.resize(unscaled, (IMAGE_WIDTH, IMAGE_HEIGHT))
feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

pred_mask = cv2.resize(1.0*(model.predict(x=np.array([feat_scaled]))[0] > 0.5), (IMAGE_WIDTH,IMAGE_HEIGHT))

image2 = image
image2[:,:,0] = pred_mask*image[:,:,0]
image2[:,:,1] = pred_mask*image[:,:,1]
image2[:,:,2] = pred_mask*image[:,:,2]

out_image = image2

plt.imshow(out_image)

# %% [markdown]
# Image Attibution : *Pinterest https://in.pinterest.com/pin/726909196083524697/*
# This image has been used solely for academic purposes.

# %%
plt.imshow(feat_scaled)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# From predictions, we can see here that the model is overfit but it is doing a decent job of identifying faces more data. In  the first image it is able to identify a female face and a raccoon face but unable to detect "Voldemort" because as we can see the face is not clearly visible once the image is scaled into RGB.

# %% [markdown]
# ## Using pre-trained weights

# %%
project_path = '/content/'

# %% [markdown]
# ### Load the model

# %%
WEIGHTS_FILE = project_path + "model-1.16.h5"
THRESHOLD = 0.8
EPSILON = 0.02

model = create_model()
model.load_weights(WEIGHTS_FILE)

# %% [markdown]
# ### Run Predictions

# %%
filename = '/content/drive/MyDrive/glearn/ACV/raccoon-25_prediction_image.jpg'

unscaled = cv2.imread(filename)
image = cv2.resize(unscaled, (IMAGE_WIDTH, IMAGE_HEIGHT))
feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

pred_mask = cv2.resize(1.0*(model.predict(x=np.array([feat_scaled]))[0] > 0.5), (IMAGE_WIDTH,IMAGE_HEIGHT))

image2 = image
image2[:,:,0] = pred_mask*image[:,:,0]
image2[:,:,1] = pred_mask*image[:,:,1]
image2[:,:,2] = pred_mask*image[:,:,2]

out_image = image2

plt.imshow(out_image)

# %%
import matplotlib.pyplot as plt
filename = '/content/drive/MyDrive/glearn/ACV/harry_1.jpg'

unscaled = cv2.imread(filename)
image = cv2.resize(unscaled, (IMAGE_WIDTH, IMAGE_HEIGHT))
feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

pred_mask = cv2.resize(1.0*(model.predict(x=np.array([feat_scaled]))[0] > 0.5), (IMAGE_WIDTH,IMAGE_HEIGHT))

image2 = image
image2[:,:,0] = pred_mask*image[:,:,0]
image2[:,:,1] = pred_mask*image[:,:,1]
image2[:,:,2] = pred_mask*image[:,:,2]

out_image = image2

plt.imshow(out_image)
